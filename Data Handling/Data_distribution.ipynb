# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

df = pd.read_csv('imdb_top_1000.csv')
imdb = pd.read_csv('IMDB Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1           Star2          Star3           Star4  No_of_Votes  \
# ...

# %%
df = df.drop(['Poster_Link', 'Overview'], axis = 1)

# %%
df.describe().T
# Out:
#               count          mean            std      min       25%       50%  \
# IMDB_Rating  1000.0       7.94930       0.275491      7.6      7.70       7.9
# Meta_score    843.0      77.97153      12.376099     28.0     70.00      79.0
# No_of_Votes  1000.0  273692.91100  327372.703934  25088.0  55526.25  138548.5
#
#                    75%        max
# IMDB_Rating       8.10        9.3
# Meta_score       87.00      100.0
# No_of_Votes  374161.25  2343110.0

# %%
sns.countplot(x = df['IMDB_Rating'], data = df, palette = 'spring')
# Out:
# <ipython-input-23-1533132160>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['IMDB_Rating'], data = df, palette = 'spring')
# <Axes: xlabel='IMDB_Rating', ylabel='count'>

# %%
figsize = plt.figure(figsize = (20,8))
sns.countplot(x = df['Released_Year'], data = df, palette = 'spring')
# Out:
# <ipython-input-35-415805217>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['Released_Year'], data = df, palette = 'spring')
# <Axes: xlabel='Released_Year', ylabel='count'>

# %%
figsize = plt.figure(figsize = (20,8))
plt.hist(df['Released_Year'])
# Out:
# (array([169., 148., 132., 128., 113., 137.,  65.,  63.,  26.,  19.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
figsize = plt.figure(figsize = (12,12))
sns.boxplot(df['Released_Year'])
# Out:
# <Axes: ylabel='Released_Year'>

# %%
figsize = plt.figure(figsize = (18,7))
sns.countplot(x = df['Certificate'], data = df, palette = 'spring')
# Out:
# <ipython-input-45-3253641436>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['Certificate'], data = df, palette = 'spring')
# <Axes: xlabel='Certificate', ylabel='count'>

# %%
imdb.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
imdb['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
sns.countplot(imdb['sentiment'])
# Out:
# <Axes: xlabel='count', ylabel='sentiment'>

# %%
sns.countplot(x = imdb['sentiment'])
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>
