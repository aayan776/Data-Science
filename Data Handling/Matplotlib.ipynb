# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

data = pd.read_csv("Iris.csv")
titan = pd.read_csv("Titanic Dataset.csv")
vacc = pd.read_csv("country_vaccinations.csv")
vacc = vacc.drop('source_website', axis = 1)
vacc = vacc.fillna(method = 'bfill')
vacc
# Out:
# /tmp/ipython-input-18-625141911.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   vacc = vacc.fillna(method = 'bfill')
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23              8200.0
# 2      Afghanistan      AFG  2021-02-24              8200.0
# 3      Afghanistan      AFG  2021-02-25              8200.0
# 4      Afghanistan      AFG  2021-02-26              8200.0
# ...            ...      ...         ...                 ...
# 25857     Zimbabwe      ZWE  2021-06-16           1120873.0
# 25858     Zimbabwe      ZWE  2021-06-17           1126087.0
# 25859     Zimbabwe      ZWE  2021-06-18           1131397.0
# 25860     Zimbabwe      ZWE  2021-06-19           1133920.0
# 25861     Zimbabwe      ZWE  2021-06-20           1138733.0
#
# ...

# %%
#Pie chart
data.groupby(titan['Survived']).size().plot(kind = 'pie', autopct = '%.2f')
plt.title('Survived - Died')
# Out:
# Text(0.5, 1.0, 'Survived - Died')

# %%
#Line plot
plt.plot(vacc['total_vaccinations'], vacc['people_fully_vaccinated'])

# %%
plt.plot(vacc['total_vaccinations_per_hundred'], vacc['people_vaccinated_per_hundred'])

# %%
plt.hist(data['PetalLengthCm'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['PetalLengthCm'], bins = [0,2,4,6,8])
# Out:
# (array([50., 11., 78., 11.]),
#  array([0., 2., 4., 6., 8.]),
#  <BarContainer object of 4 artists>)

# %%
plt.figure(figsize = (10,8))
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
y = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
plt.plot(y, blood_sugar_men, color = 'blue', label = 'Men')
plt.plot(y, blood_sugar_women, color = 'red', label = 'Women')
plt.xlabel('Average blood sugar levels of both genders')
plt.xlabel('Year')
plt.legend()
plt.show()
