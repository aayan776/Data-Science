# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
plt.figure(figsize = (12,6))
sns.barplot(data["Species"])
# Out:
# <Axes: ylabel='Species'>

# %%
#Setting subplots
fig = plt.subplots(figsize = (12,8))
barWidth = 0.25
#Administering values
IT = [12,30,1,8,22,23,15,27,10,3]
ECE = [28,6,16,5,10,16,14,11,13,29]
CSE = [29,3,24,25,17,9,21,4,6,17]
#Set positions
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
#Plotting
plt.bar(br1, IT, color = 'r', width = barWidth, label = 'IT', edgecolor = 'grey')
plt.bar(br2, ECE, color = 'g', width = barWidth, label = 'ECE', edgecolor = 'grey')
plt.bar(br3, CSE, color = 'b', width = barWidth, label = 'CSE', edgecolor = 'grey')
#Xticks
plt.xlabel('Branch', fontweight = 'bold', fontsize = 16)
plt.ylabel('Students Passed', fontweight = 'bold', fontsize = 16)
plt.xticks([r + barWidth for r in range(len(IT))], ['2015','2016','2017','2018','2019','2020','2021','2022','2023','2024'])
plt.legend()
plt.show()

# %%
sns.countplot(data = data, x = 'Species', palette = 'mako')
# Out:
# /tmp/ipython-input-3120592686.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = data, x = 'Species', palette = 'mako')
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.countplot(data = data, x = 'Species', hue = 'SepalLengthCm', palette = 'mako')
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.heatmap(data.corr(numeric_only = True), cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %%
sns.boxplot(data = data, x = 'Species', y = 'SepalWidthCm', palette = 'winter')
# Out:
# /tmp/ipython-input-2285620737.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = data, x = 'Species', y = 'SepalWidthCm', palette = 'winter')
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.swarmplot(data = data, x = 'Species', y = 'SepalWidthCm', palette = 'husl')
# Out:
# /tmp/ipython-input-3143263231.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data = data, x = 'Species', y = 'SepalWidthCm', palette = 'husl')
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>
