# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
#Dataset
data = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Apple', 'Milk'],
    ['Milk', 'Bread', 'Butter', 'Apple']
]
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns = te.columns_)
#Apriori
frequent_itemsets = apriori(df, min_support = 0.4, use_colnames = True)
rules = association_rules(frequent_itemsets, metric = 'lift', min_threshold = 1)
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#       antecedents     consequents  support  confidence      lift
# 0         (Apple)          (Milk)      0.4    1.000000  1.250000
# 1          (Milk)         (Apple)      0.4    0.500000  1.250000
# 2        (Butter)         (Bread)      0.6    1.000000  1.250000
# 3         (Bread)        (Butter)      0.6    0.750000  1.250000
# 4  (Butter, Milk)         (Bread)      0.4    1.000000  1.250000
# 5   (Milk, Bread)        (Butter)      0.4    0.666667  1.111111
# 6        (Butter)   (Milk, Bread)      0.4    0.666667  1.111111
# 7         (Bread)  (Butter, Milk)      0.4    0.500000  1.250000

# %%
x = rules[['support', 'confidence', 'lift']]
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
#Kmeans
kmeans = KMeans(n_clusters = 2, random_state = 42)
rules['cluster'] = kmeans.fit_predict(x_scaled)
print(rules[['antecedents', 'consequents', 'cluster']])
# Out:
#       antecedents     consequents  cluster
# 0         (Apple)          (Milk)        0
# 1          (Milk)         (Apple)        1
# 2        (Butter)         (Bread)        0
# 3         (Bread)        (Butter)        0
# 4  (Butter, Milk)         (Bread)        0
# 5   (Milk, Bread)        (Butter)        1
# 6        (Butter)   (Milk, Bread)        1
# 7         (Bread)  (Butter, Milk)        1

# %%
x_scaled
# Out:
# array([[-0.57735027,  1.18771489,  0.57735027],
#        [-0.57735027, -1.29099445,  0.57735027],
#        [ 1.73205081,  1.18771489,  0.57735027],
#        [ 1.73205081, -0.05163978,  0.57735027],
#        [-0.57735027,  1.18771489,  0.57735027],
#        [-0.57735027, -0.464758  , -1.73205081],
#        [-0.57735027, -0.464758  , -1.73205081],
#        [-0.57735027, -1.29099445,  0.57735027]])

# %%
x
# Out:
#    support  confidence      lift
# 0      0.4    1.000000  1.250000
# 1      0.4    0.500000  1.250000
# 2      0.6    1.000000  1.250000
# 3      0.6    0.750000  1.250000
# 4      0.4    1.000000  1.250000
# 5      0.4    0.666667  1.111111
# 6      0.4    0.666667  1.111111
# 7      0.4    0.500000  1.250000
