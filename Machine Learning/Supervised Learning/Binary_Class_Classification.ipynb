# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
#Dataset
data = pd.read_csv("country_vaccinations.csv")
data = data.interpolate()
data = data.fillna(method = 'bfill')
df = pd.read_csv('/content/Weather Dataset - Trial Activity DataSet.csv')
data.head(10)
# Out:
# /tmp/ipython-input-4039662227.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data = data.interpolate()
# /tmp/ipython-input-4039662227.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method = 'bfill')
#        country iso_code  ...                source_name            source_website
# 0  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 1  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 2  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 3  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# 4  Afghanistan      AFG  ...  World Health Organization  https://covid19.who.int/
# ...

# %%
data.isnull().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                      9838
# people_vaccinated                      10395
# people_fully_vaccinated                12563
# daily_vaccinations_raw                 12031
# daily_vaccinations                       231
# total_vaccinations_per_hundred          9838
# people_vaccinated_per_hundred          10395
# people_fully_vaccinated_per_hundred    12563
# daily_vaccinations_per_million           231
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
data.shape
# Out:
# (21980, 15)

# %%
data['country'].value_counts()
# Out:
# country
# Norway                             201
# Scotland                           193
# Canada                             189
# China                              188
# Russia                             188
#                                   ...
# Burkina Faso                        13
# Chad                                 1
# Bonaire Sint Eustatius and Saba      1
# Pitcairn                             1
# Turkmenistan                         1
# Name: count, Length: 217, dtype: int64

# %%
data.source_name.value_counts()
# Out:
# source_name
# Ministry of Health                    6732
# World Health Organization             4493
# Government of the United Kingdom       874
# SPC Public Health Division             758
# Federal Office of Public Health        321
#                                       ...
# Government of Uzbekistan                77
# Ministry of Health and Wellness         75
# Government of the Falkland Islands      67
# Government of Zambia                    63
# Government of Eswatini                  45
# Name: count, Length: 95, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x = 'total_vaccinations_per_hundred',y = 'total_vaccinations', data = data, hue = 'country')
# Out:
# <Axes: xlabel='total_vaccinations_per_hundred', ylabel='total_vaccinations'>

# %%
plt.plot('total_vaccinations', data = data)

# %%
df.head(10)
# Out:
#           date_time  is_holiday  ...  weather_type      weather_description
# 0  18-05-2017 00:00         NaN  ...          Rain            moderate rain
# 1  18-05-2017 00:00         NaN  ...          Mist                     mist
# 2  18-05-2017 00:00         NaN  ...       Drizzle  light intensity drizzle
# 3  18-05-2017 01:00         NaN  ...          Rain     heavy intensity rain
# 4  18-05-2017 01:00         NaN  ...          Mist                     mist
# 5  18-05-2017 02:00         NaN  ...          Rain     heavy intensity rain
# 6  18-05-2017 02:00         NaN  ...          Mist                     mist
# 7  18-05-2017 02:00         NaN  ...       Drizzle                  drizzle
# 8  18-05-2017 03:00         NaN  ...          Rain     heavy intensity rain
# 9  18-05-2017 03:00         NaN  ...          Mist                     mist
#
# [10 rows x 14 columns]

# %%
x = df[['visibility_in_miles']]
y = df['air_pollution_index']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 37)
model = SVC()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
plt.scatter(x = x_test, y = y_pred)

# %%
y = df['visibility_in_miles']
x = df[['air_pollution_index']]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 37)
model = SVC()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
plt.scatter(x = x_test, y = y_pred)
