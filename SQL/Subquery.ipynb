# %%
import sqlite3
database = "database.sqlite"
conn = sqlite3.connect(database)
cursor = conn.cursor()
print("Data opened successfully.")
# Out:
# Data opened successfully.

# %%
import pandas as pd
teams = pd.read_sql("""SELECT Season_Id, Man_of_the_Series FROM Season
                    WHERE Man_of_the_Series IN (SELECT Player_Id FROM Player
                    WHERE Country_Name = 1)""", conn)

# %%
teams
# Out:
#    Season_Id  Man_of_the_Series
# 0          3                133
# 1          9                  8

# %%
matches = pd.read_sql("""SELECT Season_Id, Match_Id, v.Venue_Name, c.City_Name, t.Team_Name AS Winner FROM Match
                      INNER JOIN Venue AS v ON match.Venue_Id == v.Venue_Id
                      INNER JOIN City AS c ON v.City_Id == c.City_Id
                      INNER JOIN Team AS t ON match.Match_Winner == t.Team_Id""", conn)

# %%
matches
# Out:
#      Season_Id  Match_Id                                        Venue_Name  \
# 0            1    335987                             M Chinnaswamy Stadium
# 1            1    335988        Punjab Cricket Association Stadium, Mohali
# 2            1    335989                                  Feroz Shah Kotla
# 3            1    335990                                  Wankhede Stadium
# 4            1    335991                                      Eden Gardens
# ..         ...       ...                                               ...
# 569          9    981016  Shaheed Veer Narayan Singh International Stadium
# 570          9    981018                             M Chinnaswamy Stadium
# 571          9    981020                                  Feroz Shah Kotla
# 572          9    981022                                  Feroz Shah Kotla
# 573          9    981024                             M Chinnaswamy Stadium
#
#       City_Name                       Winner
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Match""", conn)

# %%
teams
# Out:
#      Match_Id  Team_1  Team_2           Match_Date  Season_Id  Venue_Id  \
# 0      335987       2       1  2008-04-18 00:00:00          1         1
# 1      335988       4       3  2008-04-19 00:00:00          1         2
# 2      335989       6       5  2008-04-19 00:00:00          1         3
# 3      335990       7       2  2008-04-20 00:00:00          1         4
# 4      335991       1       8  2008-04-20 00:00:00          1         5
# ..        ...     ...     ...                  ...        ...       ...
# 572    981016       6       2  2016-05-22 00:00:00          9        27
# 573    981018      13       2  2016-05-24 00:00:00          9         1
# 574    981020      11       1  2016-05-25 00:00:00          9         3
# 575    981022      13      11  2016-05-27 00:00:00          9         3
# 576    981024       2      11  2016-05-29 00:00:00          9         1
#
#      Toss_Winner  Toss_Decide  Win_Type  Win_Margin  Outcome_type  \
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Venue""", conn)

# %%
teams = pd.read_sql("""SELECT * FROM City""", conn)

# %%
teams = pd.read_sql("""SELECT * FROM Team""", conn)

# %%
teams
# Out:
#     Team_Id                    Team_Name
# 0         1        Kolkata Knight Riders
# 1         2  Royal Challengers Bangalore
# 2         3          Chennai Super Kings
# 3         4              Kings XI Punjab
# 4         5             Rajasthan Royals
# 5         6             Delhi Daredevils
# 6         7               Mumbai Indians
# 7         8              Deccan Chargers
# 8         9         Kochi Tuskers Kerala
# 9        10                Pune Warriors
# 10       11          Sunrisers Hyderabad
# 11       12      Rising Pune Supergiants
# 12       13                Gujarat Lions

# %%
teams = pd.read_sql("""SELECT Match_Id, Team_2 AS Away_Team, Toss_Winner, Match_Winner FROM Match
                    WHERE Team_1 = (SELECT Team_1 FROM Match WHERE Team_1 = 3 AND Season_Id = 8)""", conn)

# %%
teams
# Out:
#     Match_Id  Away_Team  Toss_Winner  Match_Winner
# 0     335994          7            7             3
# 1     335998          1            1             3
# 2     336006          6            3             6
# 3     336012          8            8             8
# 4     336018          4            4             3
# ..       ...        ...          ...           ...
# 69    829784          2            3             3
# 70    829794          7            3             7
# 71    829802          5            3             3
# 72    829822          7            7             7
# 73    829826          2            3             3
#
# [74 rows x 4 columns]

# %%
teams = pd.read_sql("""SELECT Match_Id, Team_2 AS Away_Team, Toss_Winner, Match_Winner FROM Match
                    WHERE Team_1 = 3 AND Season_Id = 8""", conn)

# %%
teams
# Out:
#    Match_Id  Away_Team  Toss_Winner  Match_Winner
# 0    829712          6            6             3
# 1    829716         11            3             3
# 2    829758          4            3             3
# 3    829770          1            1             3
# 4    829784          2            3             3
# 5    829794          7            3             7
# 6    829802          5            3             3
# 7    829822          7            7             7
# 8    829826          2            3             3

# %%
teams = pd.read_sql("""SELECT Match_Id, Runs_Scored AS Total_Runs, Innings_No FROM Batsman_Scored
                    WHERE Total_Runs > 5 AND Match_Id IN (SELECT Match_Id FROM Match WHERE Season_Id = 8)""", conn)

# %%
teams
# Out:
#      Match_Id  Total_Runs  Innings_No
# 0      829710           6           2
# 1      829710           6           2
# 2      829710           6           1
# 3      829710           6           2
# 4      829710           6           2
# ..        ...         ...         ...
# 687    829828           6           1
# 688    829828           6           1
# 689    829828           6           2
# 690    829828           6           1
# 691    829828           6           2
#
# [692 rows x 3 columns]

# %%
teams = pd.read_sql("""SELECT MAX(Runs_Scored) FROM Batsman_Scored""", conn)

# %%
teams
# Out:
#    MAX(Runs_Scored)
# 0                 6

# %%
teams = pd.read_sql("""SELECT Match_Id, Runs_Scored AS Total_Runs, Innings_No FROM Batsman_Scored
                    WHERE Innings_No == 1 AND Runs_Scored > (SELECT AVG(Runs_Scored) FROM Batsman_Scored)""", conn)

# %%
teams
# Out:
#        Match_Id  Total_Runs  Innings_No
# 0        335987           4           1
# 1        335987           4           1
# 2        335987           6           1
# 3        335987           4           1
# 4        335987           4           1
# ...         ...         ...         ...
# 16049    981024           4           1
# 16050    981024           4           1
# 16051    981024           6           1
# 16052    981024           6           1
# 16053    981024           6           1
#
# [16054 rows x 3 columns]
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# ...

# %%
teams = pd.read_sql("""SELECT AVG(Runs_Scored) FROM Batsman_Scored""", conn)

# %%
teams
# Out:
#    AVG(Runs_Scored)
# 0          1.246918

# %%
teams = pd.read_sql("""SELECT * FROM Batsman_Scored""", conn)

# %%
teams
# Out:
#         Match_Id  Over_Id  Ball_Id  Runs_Scored  Innings_No
# 0         335987        1        1            0           1
# 1         335987        1        1            1           2
# 2         335987        1        2            0           1
# 3         335987        1        3            0           2
# 4         335987        1        4            0           1
# ...          ...      ...      ...          ...         ...
# 133092    981024       20        4            0           2
# 133093    981024       20        5            1           1
# 133094    981024       20        5            1           2
# 133095    981024       20        6            6           1
# 133096    981024       20        6            4           2
#
# [133097 rows x 5 columns]
# ...
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
teams = pd.read_sql("""SELECT * FROM sqlite_master WHERE type = 'table'""", conn)

# %%
teams
# Out:
#      type             name         tbl_name  rootpage  \
# 0   table           Player           Player         2
# 1   table       Extra_Runs       Extra_Runs         3
# 2   table   Batsman_Scored   Batsman_Scored         7
# 3   table    Batting_Style    Batting_Style        10
# 4   table    Bowling_Style    Bowling_Style        11
# 5   table          Country          Country        12
# 6   table           Season           Season        14
# 7   table             City             City        15
# 8   table          Outcome          Outcome        16
# 9   table           Win_By           Win_By        17
# 10  table     Wicket_Taken     Wicket_Taken        18
# 11  table            Venue            Venue        21
# 12  table       Extra_Type       Extra_Type        23
# 13  table         Out_Type         Out_Type        24
# 14  table    Toss_Decision    Toss_Decision        25
# 15  table           Umpire           Umpire        26
# ...

# %%
data = pd.read_sql("""SELECT * FROM Ball_by_Ball""", conn)

# %%
data
# Out:
#         Match_Id  Over_Id  Ball_Id  Innings_No  Team_Batting  Team_Bowling  \
# 0         335987        1        1           1             1             2
# 1         335987        1        1           2             2             1
# 2         335987        1        2           1             1             2
# 3         335987        1        2           2             2             1
# 4         335987        1        3           1             1             2
# ...          ...      ...      ...         ...           ...           ...
# 136585    981024       20        4           2             2            11
# 136586    981024       20        5           1            11             2
# 136587    981024       20        5           2             2            11
# 136588    981024       20        6           1            11             2
# 136589    981024       20        6           2             2            11
#
#         Striker_Batting_Position  Striker  Non_Striker  Bowler
# ...

# %%
data = pd.read_sql("""SELECT Striker, COUNT(*) AS Rate FROM Ball_by_Ball
                   GROUP BY Striker
                   ORDER BY Rate DESC
                   LIMIT 1"""
                   , conn)

# %%
data
# Out:
#    Striker  Rate
# 0        8  3237
