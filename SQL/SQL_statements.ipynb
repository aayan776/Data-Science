# %%
#Import sqlite
import sqlite3
database = "database.sqlite"
conn = sqlite3.connect(database)
print("Data opened successfully.")
# Out:
# Data opened successfully.

# %%
import pandas as pd
teams = pd.read_sql("""SELECT * FROM Match""", conn)

# %%
teams
# Out:
#      Match_Id  Team_1  Team_2           Match_Date  Season_Id  Venue_Id  \
# 0      335987       2       1  2008-04-18 00:00:00          1         1
# 1      335988       4       3  2008-04-19 00:00:00          1         2
# 2      335989       6       5  2008-04-19 00:00:00          1         3
# 3      335990       7       2  2008-04-20 00:00:00          1         4
# 4      335991       1       8  2008-04-20 00:00:00          1         5
# ..        ...     ...     ...                  ...        ...       ...
# 572    981016       6       2  2016-05-22 00:00:00          9        27
# 573    981018      13       2  2016-05-24 00:00:00          9         1
# 574    981020      11       1  2016-05-25 00:00:00          9         3
# 575    981022      13      11  2016-05-27 00:00:00          9         3
# 576    981024       2      11  2016-05-29 00:00:00          9         1
#
#      Toss_Winner  Toss_Decide  Win_Type  Win_Margin  Outcome_type  \
# ...

# %%
teams = pd.read_sql("""SELECT DISTINCT Man_of_the_Match FROM Match""", conn)

# %%
teams
# Out:
#      Man_of_the_Match
# 0                 NaN
# 1                 1.0
# 2                 2.0
# 3                 4.0
# 4                 6.0
# ..                ...
# 183             427.0
# 184             430.0
# 185             451.0
# 186             458.0
# 187             460.0
#
# [188 rows x 1 columns]

# %%
teams = pd.read_sql("""SELECT COUNT(Man_of_the_Match) FROM Match
                    GROUP BY Season_Id""", conn)

# %%
teams
# Out:
#    COUNT(Man_of_the_Match)
# 0                       58
# 1                       57
# 2                       60
# 3                       72
# 4                       74
# 5                       76
# 6                       60
# 7                       57
# 8                       60

# %%
teams = pd.read_sql("""SELECT Man_of_the_Match FROM Match
                    ORDER BY Man_of_the_Match""", conn)

# %%
teams
# Out:
#      Man_of_the_Match
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 1.0
# 4                 1.0
# ..                ...
# 572             430.0
# 573             451.0
# 574             451.0
# 575             458.0
# 576             460.0
#
# [577 rows x 1 columns]

# %%
teams = pd.read_sql("""SELECT * FROM Player
                    ORDER BY DOB""", conn)

# %%
teams

# %%
teams = pd.read_sql("""SELECT * FROM Player
                    ORDER BY DOB DESC""", conn)

# %%
teams
# Out:
#      Player_Id        Player_Name                  DOB  Batting_hand  \
# 0          410       Ishan Kishan  1998-07-18 00:00:00             1
# 1          402            SN Khan  1997-10-27 00:00:00             2
# 2          420            RR Pant  1997-10-04 00:00:00             1
# 3          432          S Kaushik  1995-09-07 00:00:00             2
# 4          460  Mustafizur Rahman  1995-09-06 00:00:00             1
# ..         ...                ...                  ...           ...
# 464         16           SB Joshi  1970-06-06 00:00:00             1
# 465        118         GD McGrath  1970-02-09 00:00:00             2
# 466         34         DS Lehmann  1970-02-05 00:00:00             1
# 467         38           SK Warne  1969-09-13 00:00:00             2
# 468         44      ST Jayasuriya  1969-06-30 00:00:00             1
#
#      Bowling_skill  Country_Name
# 0              NaN             1
# 1             10.0             1
# 2              NaN             1
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Player
                    ORDER BY DOB ASC""", conn)

# %%
teams
# Out:
#      Player_Id        Player_Name                  DOB  Batting_hand  \
# 0           44      ST Jayasuriya  1969-06-30 00:00:00             1
# 1           38           SK Warne  1969-09-13 00:00:00             2
# 2           34         DS Lehmann  1970-02-05 00:00:00             1
# 3          118         GD McGrath  1970-02-09 00:00:00             2
# 4           16           SB Joshi  1970-06-06 00:00:00             1
# ..         ...                ...                  ...           ...
# 464        460  Mustafizur Rahman  1995-09-06 00:00:00             1
# 465        432          S Kaushik  1995-09-07 00:00:00             2
# 466        420            RR Pant  1997-10-04 00:00:00             1
# 467        402            SN Khan  1997-10-27 00:00:00             2
# 468        410       Ishan Kishan  1998-07-18 00:00:00             1
#
#      Bowling_skill  Country_Name
# 0              7.0             7
# 1              4.0             5
# 2              7.0             5
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Player""", conn)

# %%
teams
# Out:
#      Player_Id      Player_Name                  DOB  Batting_hand  \
# 0            1       SC Ganguly  1972-07-08 00:00:00             1
# 1            2      BB McCullum  1981-09-27 00:00:00             2
# 2            3       RT Ponting  1974-12-19 00:00:00             2
# 3            4        DJ Hussey  1977-07-15 00:00:00             2
# 4            5  Mohammad Hafeez  1980-10-17 00:00:00             2
# ..         ...              ...                  ...           ...
# 464        465        DL Chahar  1992-08-07 00:00:00             2
# 465        466       P Dharmani  1974-09-27 00:00:00             2
# 466        467         RV Pawar  1979-09-06 00:00:00             1
# 467        468       KH Devdhar  1989-12-14 00:00:00             2
# 468        469         T Mishra  1986-12-22 00:00:00             2
#
#      Bowling_skill  Country_Name
# 0              1.0             1
# 1              1.0             4
# 2              1.0             5
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Player
                    WHERE Bowling_skill = 1.0""", conn)

# %%
teams
# Out:
#      Player_Id  Player_Name                  DOB  Batting_hand  Bowling_skill  \
# 0            1   SC Ganguly  1972-07-08 00:00:00             1              1
# 1            2  BB McCullum  1981-09-27 00:00:00             2              1
# 2            3   RT Ponting  1974-12-19 00:00:00             2              1
# 3            8      V Kohli  1988-11-05 00:00:00             2              1
# 4           11   MV Boucher  1976-12-03 00:00:00             2              1
# ..         ...          ...                  ...           ...            ...
# 99         446  Anand Rajan  1987-04-17 00:00:00             2              1
# 100        448    SS Mundhe  1988-10-27 00:00:00             2              1
# 101        454     MG Neser  1990-03-29 00:00:00             2              1
# 102        455    V Shankar  1991-01-26 00:00:00             2              1
# 103        465    DL Chahar  1992-08-07 00:00:00             2              1
#
#      Country_Name
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Player
                    WHERE Bowling_skill > 1.0""", conn)

# %%
teams
# Out:
#      Player_Id      Player_Name                  DOB  Batting_hand  \
# 0            4        DJ Hussey  1977-07-15 00:00:00             2
# 1            5  Mohammad Hafeez  1980-10-17 00:00:00             2
# 2            6         R Dravid  1973-01-11 00:00:00             2
# 3            7         W Jaffer  1978-02-16 00:00:00             2
# 4            9        JH Kallis  1975-10-16 00:00:00             2
# ..         ...              ...                  ...           ...
# 317        462    Kuldeep Yadav  1994-12-14 00:00:00             1
# 318        463         T Shamsi  1990-02-18 00:00:00             2
# 319        464        SM Boland  1989-04-11 00:00:00             2
# 320        467         RV Pawar  1979-09-06 00:00:00             1
# 321        469         T Mishra  1986-12-22 00:00:00             2
#
#      Bowling_skill  Country_Name
# 0                2             5
# 1                2             6
# 2                2             1
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Player
                    WHERE Batting_hand = 1""", conn)

# %%
teams
# Out:
#      Player_Id        Player_Name                  DOB  Batting_hand  \
# 0            1         SC Ganguly  1972-07-08 00:00:00             1
# 1           16           SB Joshi  1970-06-06 00:00:00             1
# 2           17           PA Patel  1985-03-09 00:00:00             1
# 3           18          ML Hayden  1971-10-29 00:00:00             1
# 4           19         MEK Hussey  1975-05-27 00:00:00             1
# ..         ...                ...                  ...           ...
# 121        456         K Santokie  1984-12-20 00:00:00             1
# 122        459          GS Sandhu  1993-06-14 00:00:00             1
# 123        460  Mustafizur Rahman  1995-09-06 00:00:00             1
# 124        462      Kuldeep Yadav  1994-12-14 00:00:00             1
# 125        467           RV Pawar  1979-09-06 00:00:00             1
#
#      Bowling_skill  Country_Name
# 0              1.0             1
# 1              7.0             1
# 2              NaN             1
# ...

# %%
teams = pd.read_sql("""SELECT * FROM Player
                    WHERE Batting_hand = 2""", conn)

# %%
teams
# Out:
#      Player_Id      Player_Name                  DOB  Batting_hand  \
# 0            2      BB McCullum  1981-09-27 00:00:00             2
# 1            3       RT Ponting  1974-12-19 00:00:00             2
# 2            4        DJ Hussey  1977-07-15 00:00:00             2
# 3            5  Mohammad Hafeez  1980-10-17 00:00:00             2
# 4            6         R Dravid  1973-01-11 00:00:00             2
# ..         ...              ...                  ...           ...
# 338        464        SM Boland  1989-04-11 00:00:00             2
# 339        465        DL Chahar  1992-08-07 00:00:00             2
# 340        466       P Dharmani  1974-09-27 00:00:00             2
# 341        468       KH Devdhar  1989-12-14 00:00:00             2
# 342        469         T Mishra  1986-12-22 00:00:00             2
#
#      Bowling_skill  Country_Name
# 0              1.0             4
# 1              1.0             5
# 2              2.0             5
# ...

# %%
teams = pd.read_sql("""SELECT COUNT(*) FROM Player
                    GROUP BY Bowling_skill
                    LIMIT 1""", conn)

# %%
teams
# Out:
#    COUNT(*)
# 0        43

# %%
teams = pd.read_sql("""SELECT COUNT(*) FROM Player
                    WHERE Bowling_skill IS NULL""", conn)

# %%
teams
# Out:
#    COUNT(*)
# 0        43

# %%
teams = pd.read_sql("""SELECT COUNT(Match_Id) FROM Match
                    WHERE Match_Winner = 7""", conn)

# %%
teams
# Out:
#    COUNT(Match_Id)
# 0               80

# %%
teams = pd.read_sql("""SELECT SUM(Extra_Runs) FROM Extra_Runs""", conn)

# %%
teams
# Out:
#    SUM(Extra_Runs)
# 0             9514

# %%
teams = pd.read_sql("""SELECT COUNT(Player_Id), Country_Name FROM Player
                    GROUP BY Country_Name""", conn)

# %%
teams
# Out:
#     COUNT(Player_Id)  Country_Name
# 0                262             1
# 1                 39             2
# 2                 22             4
# 3                 72             5
# 4                 13             6
# 5                 20             7
# 6                 19             8
# 7                  2             9
# 8                 14            10
# 9                  5            11
# 10                 1            12

# %%
result1 = pd.read_sql("""SELECT Match_Winner, ROUND(AVG(Win_Margin)) FROM Match
                    WHERE Season_Id = 9
                    GROUP BY Match_Winner
                    ORDER BY ROUND(AVG(Win_Margin))""", conn)

# %%
result1
# Out:
#    Match_Winner  ROUND(AVG(Win_Margin))
# 0            13                     5.0
# 1             1                     8.0
# 2             6                    10.0
# 3             4                    11.0
# 4            12                    15.0
# 5            11                    16.0
# 6             7                    20.0
# 7             2                    35.0

# %%
result2 = pd.read_sql("""SELECT COUNT(DISTINCT Venue_Id) FROM Match
                    WHERE Season_Id = 9""", conn)

# %%
result2
# Out:
#    COUNT(DISTINCT Venue_Id)
# 0                        11

# %%
result3 = pd.read_sql("""SELECT
                      MAX(Win_Margin), MIN(Win_Margin), ROUND(AVG(Win_Margin)), COUNT(DISTINCT Man_of_the_Match) FROM Match
                      WHERE Season_Id = 9""", conn)

# %%
result3
# Out:
#    MAX(Win_Margin)  MIN(Win_Margin)  ROUND(AVG(Win_Margin))  \
# 0              144                1                    15.0
#
#    COUNT(DISTINCT Man_of_the_Match)
# 0                                36
