# %%
def find_prob(a,b):
  if a == 1:
    prob_a = 0.2
    if b == 1:
      prob_bga = 0.85
    elif b == 2:
      prob_bga = 0.15
    else:
      print('Invalid answer')
    prob_a_and_b = prob_a * prob_bga
    print('Probability of b given a:', prob_bga)
    print('Probability of both a and b happening:', prob_a_and_b)
  if a == 2:
    prob_a = 0.8
    if b == 1:
      prob_bga = 0.02
    elif b == 2:
      prob_bga = 0.98
    else:
      print('Invalid answer')
    prob_a_and_b = prob_a * prob_bga
    print('Probability of b given a:', prob_bga)
    print('Probability of both a and b happening:', prob_a_and_b)
print(('Do you have step throat? \n 1.Yes \n 2.No'))
a = int(input('Enter choice: '))
print(('Was your test positive? \n 1.Yes \n 2.No'))
b = int(input('Enter choice: '))
find_prob(a,b)
# Out:
# Do you have step throat?
#  1.Yes
#  2.No
# Enter choice: 1
# Was your test positive?
#  1.Yes
#  2.No
# Enter choice: 2
# Probability of b given a: 0.15
# Probability of both a and b happening: 0.03

# %%
prob_st = 0.2
prob_st_pos = 0.2 * 0.85
prob_nst_pos = 0.8 * 0.02
prob_positive = prob_st_pos + prob_nst_pos
prob_pos_given_st = 0.85

prob_result = (prob_pos_given_st * prob_st)/prob_positive
print(prob_result)
# Out:
# 0.913978494623656

# %%
import scipy.stats as stat
x = 3
n = 10
prob1 = stat.binom.pmf(x,n,0.5)
print('Probabgility of getting three heads:', prob1)

prob2 = 1 - stat.binom.pmf(0,n, p = 0.5) - stat.binom.pmf(1,n, p = 0.5) - stat.binom.pmf(2,n, p = 0.5)
print('Probabgility of getting more than 2 heads:', prob2)
# Out:
# Probabgility of getting three heads: 0.1171875
# Probabgility of getting more than 2 heads: 0.9453125
