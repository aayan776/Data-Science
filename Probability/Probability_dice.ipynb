# %%
import random
dice = [1,2,3,4,5,6]
result = random.choice(dice)
prob = dice.count(6)/len(dice)
print('You rolled:', result)
print('Probability of six:', prob)
# Out:
# You rolled: 4
# Probability of six: 0.16666666666666666
